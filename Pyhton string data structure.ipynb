# %%
s="Welcome To LJ"
s.upper()
s.lower()
# Out:
# 'welcome to lj'

# %%
s.title()#lower and uper mix
# Out:
# 'Welcome To Lj'

# %%
s.split()#words ko sperate kar ne k liye
# Out:
# ['Welcome', 'To', 'LJ']

# %%
s.split(sep="o",maxsplit=2)
# Out:
# ['Welc', 'me T', ' LJ']

# %%
s="Welcome To LJ for AICW 2.0 progra"#Starting spaces or ending spaces remove hota hai
s.strip()
# Out:
# 'Welcome To LJ for AICW 2.0 progra'

# %%
s.rstrip()#Right side ka space remove hota hai
# Out:
# 'Welcome To LJ for AICW 2.0 progra'

# %%
s[5]
# Out:
# 'm'

# %%
s[2:10]
# Out:
# 'lcome To'

# %%
s[2:18:3]
# Out:
# [20]

# %%
s="Edunet Foundation"
s.split()
# Out:
# ['Edunet', 'Foundation']

# %%
s=[10,20,15,56,78]
sr=sorted(s)
print(sr)
print(s)
# Out:
# [10, 15, 20, 56, 78]
# [10, 20, 15, 56, 78]

# %%
s=[10,20,15,56,78]
sr=s.sort()
print(sr)
print(s)
# Out:
# None
# [10, 15, 20, 56, 78]

# %%
t=("jiya",12,4500,"priya",23.45)
print(type(t))
# Out:
# <class 'tuple'>

# %%
sub={5,2,8}
sub.difference({5,1})#commen nahi hai wo aayega
# Out:
# {2, 8}

# %%
sub.issubset({5,1})#commen hoga to true else false
# Out:
# False

# %%
sub.issuperset({5,1})#sare part ho to hi true aayega
# Out:
# False

# %%
#Dictinary
cars={
    "brand":"BMW",
    "model":"C4",
    "year":2010
}
print(cars)
print(type(cars))
# Out:
# {'brand': 'BMW', 'model': 'C4', 'year': 2010}
# <class 'dict'>

# %%
cars["model"]
# Out:
# 'C4'

# %%
print(cars['year'])
# Out:
# 2010

# %%
#Dict methods
#print only key values
print(cars.keys())
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
cars.items()
# Out:
# dict_items([('brand', 'BMW'), ('model', 'C4'), ('year', 2010)])

# %%
cars.update({"year":2012})
cars
# Out:
# {'brand': 'BMW', 'model': 'C4', 'year': 2012}

# %%
cars.update({"brand":"mahindra"})
cars
# Out:
# {'brand': 'mahindra', 'model': 'C4', 'year': 2012}

# %%
cars["color"]="black"#TO Add key-value pair
print(cars)
# Out:
# {'brand': 'mahindra', 'model': 'C4', 'year': 2012, 'color': 'black'}

# %%
cars.pop('color')
cars
# Out:
# {'brand': 'mahindra', 'model': 'C4', 'year': 2012}
